# %% [markdown]
# <a href="https://colab.research.google.com/github/RISHIEDABOYINA/Rishi/blob/main/Lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
list=[1,2,3]
array1 = np.array(list)
array1
import numpy as np
list=[1,2,3]
array1 = np.array(list)
array1
input
list2 = [3,2,1]
array2=np.array(list2)
array2
input
people = ['subani','rishi','sharan','ram','vishal']
age = [25,22,18,25,20]
weight = [58,55,45,59,53]
height = [130,114,153,135,130]
import matplotlib.pyplot as plt
plt.scatter(weight,height)
plt.title("Relationship between weight and height of patients")
plt.ylabel("height in meters")
plt.xlabel("weight in patients in kgs")
plt.show()
people = ['subhani','rishi','sharan','ram','vishal']
age = [25,30,26,25,20]
weight = [58,55,49,57,52]
height = [127,134,143,155,150]
import matplotlib.pyplot as plt
plt.scatter(age,weight)
plt.title("Relationship between age and weight of patients")
plt.ylabel("age")
plt.xlabel("weight in patients in kgs")
plt.show()
#histogram
import numpy as np
plt.figure(figsize=(7,5))
#main plot function 'hist'
plt.hist(weight,color='red',edgecolor='k',alpha=0.75,bins=5)
plt.title("histogram of patient weight",fontsize=18)
plt.xlabel("weight(in kgs)",fontsize=15)
#plt.xticks(fontsize=15)
#plt.yticks(fontsize=15)
plt.show()
#generate Bar Plot
plt.figure(figsize=(12,4))
plt.title("people's weight in kgs",fontsize=16,fontstyle='italic')

#main plot function 'bar'
plt.bar(x=people, height=weight, width=0.6,color="blue",edgecolor='k',alpha=0.6)
plt.xlabel("people",fontsize=15)
plt.ylabel("weight(in kgs)",fontsize=15)
plt.show()
